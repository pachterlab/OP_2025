# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pachterlab/OP_2025/blob/main/analysis_scripts/9_Rat_Omic_Loading.ipynb)

# %% [markdown]
# # Clone github repo

# %%
# !git clone https://github.com/pachterlab/OP_2025.git
# %cd /content/OP_2025/

# %% [markdown]
# # Download Data

# %%
# !mkdir -p omics_data
# !wget -O omics_data/rat_ACETYL.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_ACETYL.h5ad?download=1
# !wget -O omics_data/rat_ATAC.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_ATAC.h5ad?download=1
# !wget -O omics_data/rat_IMMUNO.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_IMMUNO.h5ad?download=1
# !wget -O omics_data/rat_METAB.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_METAB.h5ad?download=1
# !wget -O omics_data/rat_METHYL.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_METHYL.h5ad?download=1
# !wget -O omics_data/rat_PHOSPHO.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_PHOSPHO.h5ad?download=1
# !wget -O omics_data/rat_PROT.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_PROT.h5ad?download=1
# !wget -O omics_data/rat_UBIQ.h5ad https://data.caltech.edu/records/j57wp-0pp06/files/rat_UBIQ.h5ad?download=1

# !wget -O omics_data/feature_to_gene.csv https://data.caltech.edu/records/j57wp-0pp06/files/feature_to_gene.csv?download=1
# !wget -O omics_data/ATAC_features.csv https://data.caltech.edu/records/j57wp-0pp06/files/ATAC_features.csv?download=1
# !wget -O omics_data/methyl_features.csv https://data.caltech.edu/records/j57wp-0pp06/files/methyl_features.csv?download=1

# %% [markdown]
# # Install Packages

# %%
# !pip install -qr requirements.txt

# %%
# import packages

import sys, os
sys.path.append('analysis_scripts')

# numbers
import numpy as np
import pandas as pd

import anndata

# %%
import os
# In Colab, %cd already set CWD to repo root; locally the notebook runs from analysis_scripts/
if not os.path.exists('analysis_scripts'):
    os.chdir('../')

# %% [markdown]
# # Metadata Loading

# %%
combined_meta = pd.read_csv('metadata_csvs/rat_nid_metadata.csv')
combined_meta
# Out:
#            pid    viallabel  calculated.variables.pct_body_fat_change  \
# 0     10023259  90217013001                                       1.8
# 1     10023259  90217013104                                       1.8
# 2     10023259  90217013105                                       1.8
# 3     10023259  90217013106                                       1.8
# 4     10023259  90217013107                                       1.8
# ...        ...          ...                                       ...
# 6151  10971645  90587017012                                       NaN
# 6152  10971645  90587017013                                       NaN
# 6153  10971645  90587017014                                       NaN
# 6154  10971645  90587017702                                       NaN
# 6155  10972374  90588013104                                       NaN
#
#       calculated.variables.pct_body_lean_change  \
# 0                                           6.9
# ...

# %% [markdown]
# # Metadata annotation of Omic Assays

# %%
for omic in ['ATAC', 'ACETYL', 'PROT', 'PHOSPHO', 'UBIQ', 'METAB','IMMUNO']:
    print(omic)
    adata = anndata.read_h5ad(f'omics_data/rat_{omic}.h5ad')
    adata.X = np.nan_to_num(adata.X, nan=0)

    # Metabolomics and Immunoassay require different, analysis-specific preprocessing due to each encompassing multiple assays
    if omic in ['METAB', 'IMMUNO']:
        adata.obs['pid'] = adata.obs['pid'].astype('int')
        temp = pd.merge(adata.obs.reset_index(), combined_meta, on=['pid', 'tissue'], how='left', suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)').set_index('index')
        temp = temp.groupby(['pid', 'tissue']).first().reset_index().drop('viallabel',axis=1)
        adata.obs = pd.merge(adata.obs.reset_index(), temp, on=['pid', 'tissue'], how='left', suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)').drop('index',axis=1).rename(index=str)
    else:
        adata.obs['viallabel'] = adata.obs.X.astype('int')
        adata.obs = pd.merge(adata.obs.reset_index(), combined_meta, on='viallabel', how='left', suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)').set_index('index')
    # add gene to feature annotations for ATAC and PROT
    if omic in ['ATAC']:
        features = pd.read_csv(f'metadata_csvs/{omic}_features.csv')
        adata.var = pd.merge(adata.var, features, left_on = 'X', right_on = 'feature_ID', how = 'left').drop('X',axis=1).rename(index=str)
        adata.var.chrom = adata.var.chrom.astype('str')
        adata.var.feature_ID = adata.var.feature_ID.astype('str')
    elif omic in ['PROT']:
        features = pd.read_csv('metadata_csvs/feature_to_gene.csv')
        temp_var = pd.merge(adata.var, features, left_on = 'X', right_on = 'feature_ID', how = 'left').drop('X',axis=1)
        temp_var = temp_var.groupby('feature_ID').first().reset_index()
        adata.var = pd.merge(adata.var, temp_var, left_on = 'X', right_on = 'feature_ID', how = 'left').drop('X',axis=1).rename(index=str)
        adata.var.feature_ID = adata.var.feature_ID.astype('str')
        adata.var.custom_annotation = adata.var.custom_annotation.astype('str')
        adata.var.kegg_id = adata.var.kegg_id.astype('str')
    # rename WAT for consistency 
    adata.obs = adata.obs.replace('WAT-SC', 'WAT')
    # only keep samples with time metadata
    adata = adata[~adata.obs.time.isna()].copy()
    rna_cols = [c for c in ['barcode', 'path', 'nac_path', 'mat_path', 'amb_path'] if c in adata.obs.columns]
    if rna_cols:
        adata.obs = adata.obs.drop(columns=rna_cols)
    for col in adata.obs.select_dtypes(include='category').columns:
        adata.obs[col] = pd.Categorical(adata.obs[col])
    adata.write(f'omics_data/rat_{omic}_meta.h5ad')

# %% [markdown]
# # Methyl Data Loading

# %% [markdown]
# Extra Processing Required because R memory limits did not allow for the merging of the Methyl dataset

# %%
meth_adata_1 = anndata.read_h5ad('omics_data/rat_METHYL_1.h5ad')
meth_adata_2 = anndata.read_h5ad('omics_data/rat_METHYL_2.h5ad')
meth_adata_3 = anndata.read_h5ad('omics_data/rat_METHYL_3.h5ad')
all_present = list(set(meth_adata_1.var.X) & set(meth_adata_2.var.X) & set(meth_adata_3.var.X))
filt_1 = meth_adata_1[:,meth_adata_1.var.X.isin(all_present)].copy()
filt_1.var.index = filt_1.var.X.astype(str)
filt_2 = meth_adata_2[:,meth_adata_2.var.X.isin(all_present)].copy()
filt_2.var.index = filt_2.var.X.astype(str)
filt_3 = meth_adata_3[:,meth_adata_3.var.X.isin(all_present)].copy()
filt_3.var.index = filt_3.var.X.astype(str)
inner_adata = anndata.concat([filt_1, filt_2, filt_3], axis = 0)
inner_adata
# Out:
# AnnData object with n_obs × n_vars = 400 × 1023169
#     obs: 'X'

# %%
ufilt_1 = meth_adata_1[:,~meth_adata_1.var.X.isin(all_present)].copy()
ufilt_1.var.index = ufilt_1.var.X.astype(str)
ufilt_2 = meth_adata_2[:,~meth_adata_2.var.X.isin(all_present)].copy()
ufilt_2.var.index = ufilt_2.var.X.astype(str)
ufilt_3 = meth_adata_3[:,~meth_adata_3.var.X.isin(all_present)].copy()
ufilt_3.var.index = ufilt_3.var.X.astype(str)
outer_adata = anndata.concat([ufilt_1, ufilt_2, ufilt_3], axis = 0, join = 'outer')
outer_adata
# Out:
# AnnData object with n_obs × n_vars = 400 × 566365
#     obs: 'X'

# %%
meth_adata = anndata.concat([inner_adata, outer_adata], axis = 1, join = 'outer')
meth_adata.obs['viallabel'] = meth_adata.obs.index.astype('int')
meth_adata.layers['counts'] = meth_adata.X
meth_adata
# Out:
# AnnData object with n_obs × n_vars = 400 × 1589534
#     obs: 'viallabel'
#     layers: 'counts'

# %%
meth_adata.obs = pd.merge(meth_adata.obs.reset_index(), combined_meta, on='viallabel', how='left', suffixes=('', '_DROP')).filter(regex='^(?!.*_DROP)').set_index('index')
meth_adata.obs = meth_adata.obs.replace('WAT-SC', 'WAT')
meth_adata

# %%
meth_features = pd.read_csv('metadata_csvs/methyl_features.csv')
meth_features = meth_features.groupby('feature_ID').first().drop('tissue', axis=1).reset_index()
meth_adata.var = pd.merge(meth_adata.var, meth_features, left_on = 'X', right_on = 'feature_ID', how = 'left')
# connect features to genes
features = pd.read_csv('metadata_csvs/feature_to_gene.csv')
temp_var = pd.merge(meth_adata.var, features, left_on = 'feature_ID', right_on = 'feature_ID', how = 'left')
temp_var = temp_var.groupby('feature_ID').first().reset_index().drop('kegg_id',axis=1)
meth_adata.var = temp_var
meth_adata.var.head()
# Out:
# /var/folders/kj/wm2vrp3x04qgzq18l2rkrcxh0000gn/T/ipykernel_10531/50420824.py:5: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   features = pd.read_csv('metadata_csvs/feature_to_gene.csv')
#              feature_ID  Chr              Locus EntrezID Symbol Strand  Width  \
# 0           chr1-100093    1  50046723-50046723    56816   Prkn      -      0
# 1           chr1-100094    1  50046775-50046775    56816   Prkn      -      0
# 2            chr1-10020    1    5010178-5010178    24414   Grm1      -      0
# 3            chr1-10021    1    5010265-5010265    24414   Grm1      -      0
# 4  chr1-100227_cluster1    1  50113565-50113565   499021  Pacrg      +      0
#
#    NumSites     Sites  LocStart    LocEnd  entrez_gene    rgd_gene  \
# 0         1  50046723  50046723  50046723          NaN  15009540.0
# 1         1  50046775  50046775  50046775          NaN  15009540.0
# ...

# %%
# drop columns missing data
meth_adata = meth_adata[:,~np.isnan(meth_adata.X).any(axis=0)].copy()
meth_adata

# %%
rna_cols = [c for c in ['barcode', 'path', 'nac_path', 'mat_path', 'amb_path'] if c in meth_adata.obs.columns]
if rna_cols:
    meth_adata.obs = meth_adata.obs.drop(columns=rna_cols)
for col in meth_adata.obs.select_dtypes(include='category').columns:
    meth_adata.obs[col] = pd.Categorical(meth_adata.obs[col])
meth_adata.write('omics_data/rat_METHYL_meta.h5ad')
meth_adata
# Out:
# /Users/ConradOakes/miniforge3/envs/rat_help/lib/python3.11/site-packages/anndata/_core/anndata.py:1138: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /Users/ConradOakes/miniforge3/envs/rat_help/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/ConradOakes/miniforge3/envs/rat_help/lib/python3.11/site-packages/anndata/_core/anndata.py:1138: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /Users/ConradOakes/miniforge3/envs/rat_help/lib/python3.11/site-packages/anndata/_core/anndata.py:1138: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# ...
